# %%
# %run "/Workspace/Users/tlyemul@gmail.com/axa/day5_medallion_Jobs/includes"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
dbutils.widgets.text("catalog","")
dbutils.widgets.text("table","")
catalog=dbutils.widgets.get("catalog")
table=dbutils.widgets.get("table")

# %%
df=spark.read.csv(f"{input_path}{table}.csv",header=True,inferSchema=True)

df1=add_ingestion_metadata(df)

df1.write.mode("overwrite").saveAsTable(f"{catalog}.naval_bronze.{table}")
