# %%
COPY INTO dev.akshay_bronze.sales_incremental
FROM '/Volumes/dev/akshay/akshay_volume/months/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

# %%
# %sql
COPY INTO dev.akshay_bronze.sales_incremental
FROM '/Volumes/dev/akshay/akshay_volume/months/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');
